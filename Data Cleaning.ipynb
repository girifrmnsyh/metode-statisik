# %%
# import package
import pandas as pd
import numpy as np

# %%
# import data
data = pd.read_csv('data/data_kos_its.csv', sep=',')
data
# Out:
#                                  Nama              Lokasi  \
# 0       Kost Mahasiswa Keputih Tipe B  Kecamatan Sukolilo
# 1                       Kost Griya 4S            Sukolilo
# 2          Kost Klampis Aji II Tipe C  Kecamatan Sukolilo
# 3        Kost Bumi Marina Emas Tipe B            Sukolilo
# 4                          Kost Hub E  Kecamatan Sukolilo
# ..                                ...                 ...
# 95        Kost Park Regency Exevutive            Sukolilo
# 96  Kost Bougenville 4 SPR B21 Deluxe  Kecamatan Sukolilo
# 97                      Kost Obie SPI           Mulyorejo
# 98   Kost Ardina House Keputih Tipe A            Sukolilo
# 99                 Kost Azalia Wisper           Mulyorejo
#
#                                             Fasilitas Review        Harga
# 0                     WiFi·AC·Kloset Duduk·Kasur\n4.6    4.6  Rp1.267.000
# 1   K. Mandi Dalam·WiFi·AC·Kloset Duduk·Kasur·Akse...    4.6  Rp1.286.000
# 2                        WiFi·Kloset Duduk·Kasur\n4.5    4.5    Rp849.500
# 3                        WiFi·Kasur·Akses 24 Jam\n4.1    4.1    Rp786.600
# 4   K. Mandi Dalam·WiFi·AC·Kloset Duduk·Kasur·Akse...    NaN  Rp2.200.000
# ..                                                ...    ...          ...
# 95            WiFi·AC·Kloset Duduk·Kasur·Akses 24 Jam      -  Rp1.150.000
# 96                         WiFi·AC·Kloset Duduk·Kasur      -  Rp1.749.999
# 97          K. Mandi Dalam·WiFi·AC·Kloset Duduk·Kasur      -  Rp1.500.000
# 98                            WiFi·Kloset Duduk·Kasur      -    Rp800.000
# 99                         WiFi·AC·Kloset Duduk·Kasur      -  Rp1.500.000
#
# [100 rows x 5 columns]

# %% [markdown]
# ### Lokasi

# %%
data['Lokasi'].unique()
# Out:
# array(['Kecamatan Sukolilo', 'Sukolilo', 'Kecamatan Mulyorejo',
#        'Mulyorejo'], dtype=object)

# %%
# delete 'Kelurahan' in colom 'Lokasi'.

location = []

for d in data['Lokasi']:
    location.append(d.split()[-1])

location
# Out:
# ['Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Mulyorejo',
#  'Sukolilo',
#  'Sukolilo',
#  'Mulyorejo',
#  'Sukolilo',
#  'Sukolilo',
#  'Mulyorejo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Mulyorejo',
#  'Sukolilo',
#  'Mulyorejo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Mulyorejo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Mulyorejo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Mulyorejo',
#  'Mulyorejo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Mulyorejo',
#  'Mulyorejo',
#  'Sukolilo',
#  'Sukolilo',
#  'Mulyorejo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Mulyorejo',
#  'Sukolilo',
#  'Sukolilo',
#  'Mulyorejo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Mulyorejo',
#  'Sukolilo',
#  'Mulyorejo',
#  'Sukolilo',
#  'Mulyorejo',
#  'Mulyorejo',
#  'Sukolilo',
#  'Sukolilo',
#  'Mulyorejo',
#  'Sukolilo',
#  'Sukolilo',
#  'Mulyorejo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Mulyorejo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Sukolilo',
#  'Mulyorejo',
#  'Sukolilo',
#  'Mulyorejo']

# %%
# change value
data['Lokasi'] = location

# %%
data.head()
# Out:
#                             Nama    Lokasi  \
# 0  Kost Mahasiswa Keputih Tipe B  Sukolilo
# 1                  Kost Griya 4S  Sukolilo
# 2     Kost Klampis Aji II Tipe C  Sukolilo
# 3   Kost Bumi Marina Emas Tipe B  Sukolilo
# 4                     Kost Hub E  Sukolilo
#
#                                            Fasilitas Review        Harga
# 0                    WiFi·AC·Kloset Duduk·Kasur\n4.6    4.6  Rp1.267.000
# 1  K. Mandi Dalam·WiFi·AC·Kloset Duduk·Kasur·Akse...    4.6  Rp1.286.000
# 2                       WiFi·Kloset Duduk·Kasur\n4.5    4.5    Rp849.500
# 3                       WiFi·Kasur·Akses 24 Jam\n4.1    4.1    Rp786.600
# 4  K. Mandi Dalam·WiFi·AC·Kloset Duduk·Kasur·Akse...    NaN  Rp2.200.000

# %% [markdown]
# ### Fasilitas

# %%
# change '·' to ',' and throw the ratings

facilities = []

for d in data['Fasilitas']:
    L = d.split('\n')[0]
    facilities.append(L.replace('·',', '))

facilities[:10]
# Out:
# ['WiFi, AC, Kloset Duduk, Kasur',
#  'K. Mandi Dalam, WiFi, AC, Kloset Duduk, Kasur, Akses 24 Jam',
#  'WiFi, Kloset Duduk, Kasur',
#  'WiFi, Kasur, Akses 24 Jam',
#  'K. Mandi Dalam, WiFi, AC, Kloset Duduk, Kasur, Akses 24 Jam',
#  'K. Mandi Dalam, WiFi, AC, Kloset Duduk, Kasur',
#  'WiFi, AC, Kloset Duduk, Kasur',
#  'WiFi, AC, Kloset Duduk, Kasur',
#  'K. Mandi Dalam, WiFi, AC, Kloset Duduk, Kasur',
#  'WiFi, Kasur, Akses 24 Jam']

# %%
# change value
data['Fasilitas'] = facilities

# %%
data.head()
# Out:
#                             Nama    Lokasi  \
# 0  Kost Mahasiswa Keputih Tipe B  Sukolilo
# 1                  Kost Griya 4S  Sukolilo
# 2     Kost Klampis Aji II Tipe C  Sukolilo
# 3   Kost Bumi Marina Emas Tipe B  Sukolilo
# 4                     Kost Hub E  Sukolilo
#
#                                            Fasilitas Review        Harga
# 0                      WiFi, AC, Kloset Duduk, Kasur    4.6  Rp1.267.000
# 1  K. Mandi Dalam, WiFi, AC, Kloset Duduk, Kasur,...    4.6  Rp1.286.000
# 2                          WiFi, Kloset Duduk, Kasur    4.5    Rp849.500
# 3                          WiFi, Kasur, Akses 24 Jam    4.1    Rp786.600
# 4  K. Mandi Dalam, WiFi, AC, Kloset Duduk, Kasur,...    NaN  Rp2.200.000

# %% [markdown]
# ### Harga

# %%
# remove 'Rp' and '.'

prices = []

for d in data['Harga']:
    p = d.replace('Rp','')
    p2 = p.replace('.','')
    prices.append(int(p2))

prices[:5]
# Out:
# [1267000, 1286000, 849500, 786600, 2200000]

# %%
data['Harga'] = prices

data
# Out:
#                                  Nama     Lokasi  \
# 0       Kost Mahasiswa Keputih Tipe B   Sukolilo
# 1                       Kost Griya 4S   Sukolilo
# 2          Kost Klampis Aji II Tipe C   Sukolilo
# 3        Kost Bumi Marina Emas Tipe B   Sukolilo
# 4                          Kost Hub E   Sukolilo
# ..                                ...        ...
# 95        Kost Park Regency Exevutive   Sukolilo
# 96  Kost Bougenville 4 SPR B21 Deluxe   Sukolilo
# 97                      Kost Obie SPI  Mulyorejo
# 98   Kost Ardina House Keputih Tipe A   Sukolilo
# 99                 Kost Azalia Wisper  Mulyorejo
#
#                                             Fasilitas Review    Harga
# 0                       WiFi, AC, Kloset Duduk, Kasur    4.6  1267000
# 1   K. Mandi Dalam, WiFi, AC, Kloset Duduk, Kasur,...    4.6  1286000
# 2                           WiFi, Kloset Duduk, Kasur    4.5   849500
# 3                           WiFi, Kasur, Akses 24 Jam    4.1   786600
# 4   K. Mandi Dalam, WiFi, AC, Kloset Duduk, Kasur,...    NaN  2200000
# ..                                                ...    ...      ...
# 95        WiFi, AC, Kloset Duduk, Kasur, Akses 24 Jam      -  1150000
# 96                      WiFi, AC, Kloset Duduk, Kasur      -  1749999
# 97      K. Mandi Dalam, WiFi, AC, Kloset Duduk, Kasur      -  1500000
# 98                          WiFi, Kloset Duduk, Kasur      -   800000
# 99                      WiFi, AC, Kloset Duduk, Kasur      -  1500000
#
# [100 rows x 5 columns]

# %%
data.to_csv('data/data_kos_its_clean.csv', index=False)

# %%
# check duplicated name
data['Nama'].duplicated().sum()
# Out:
# 0
